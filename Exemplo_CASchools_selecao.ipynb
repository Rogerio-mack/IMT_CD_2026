# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/IMT_CD_2026/blob/main/Exemplo_CASchools_selecao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/AER/CASchools.csv")
df = df.drop(columns="rownames")
df.head()
# Out:
#    district                           school   county grades  students  \
# 0     75119               Sunol Glen Unified  Alameda  KK-08       195
# 1     61499             Manzanita Elementary    Butte  KK-08       240
# 2     61549      Thermalito Union Elementary    Butte  KK-08      1550
# 3     61457  Golden Feather Union Elementary    Butte  KK-08       243
# 4     61523         Palermo Union Elementary    Butte  KK-08      1335
#
#     teachers   calworks      lunch  computer  expenditure     income  \
# 0  10.900000   0.510200   2.040800        67  6384.911133  22.690001
# 1  11.150000  15.416700  47.916698       101  5099.380859   9.824000
# 2  82.900002  55.032299  76.322601       169  5501.954590   8.978000
# 3  14.000000  36.475399  77.049202        85  7101.831055   8.978000
# 4  71.500000  33.108601  78.427002       171  5235.987793   9.080333
#
#      english        read        math
# 0   0.000000  691.599976  690.000000
# 1   4.583333  660.500000  661.900024
# ...

# %% [markdown]
# # Explorando a estrutura

# %%
df.shape
# Out:
# (420, 14)

# %%
len(df)
# Out:
# 420

# %%
df.columns
# Out:
# Index(['district', 'school', 'county', 'grades', 'students', 'teachers',
#        'calworks', 'lunch', 'computer', 'expenditure', 'income', 'english',
#        'read', 'math'],
#       dtype='object')

# %%
df.describe(include='all')
# Out:
#             district                    school  county grades      students  \
# count     420.000000                       420     420    420    420.000000
# unique           NaN                       409      45      2           NaN
# top              NaN  Mountain View Elementary  Sonoma  KK-08           NaN
# freq             NaN                         3      29    359           NaN
# mean    67472.809524                       NaN     NaN    NaN   2628.792857
# std      3466.994655                       NaN     NaN    NaN   3913.104985
# min     61382.000000                       NaN     NaN    NaN     81.000000
# 25%     64307.750000                       NaN     NaN    NaN    379.000000
# 50%     67760.500000                       NaN     NaN    NaN    950.500000
# 75%     70419.000000                       NaN     NaN    NaN   3008.000000
# max     75440.000000                       NaN     NaN    NaN  27176.000000
#
# ...

# %%
df.dtypes
# Out:
# district         int64
# school          object
# county          object
# grades          object
# students         int64
# teachers       float64
# calworks       float64
# lunch          float64
# computer         int64
# expenditure    float64
# income         float64
# english        float64
# read           float64
# math           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   district     420 non-null    int64
#  1   school       420 non-null    object
#  2   county       420 non-null    object
#  3   grades       420 non-null    object
#  4   students     420 non-null    int64
#  5   teachers     420 non-null    float64
#  6   calworks     420 non-null    float64
#  7   lunch        420 non-null    float64
#  8   computer     420 non-null    int64
#  9   expenditure  420 non-null    float64
#  10  income       420 non-null    float64
#  11  english      420 non-null    float64
#  12  read         420 non-null    float64
#  13  math         420 non-null    float64
# dtypes: float64(8), int64(3), object(3)
# memory usage: 46.1+ KB

# %% [markdown]
# # Automatic EDA
#
# Opções: Sweetviz, Autoviz, YData Profiling (antigo Pandas Profiling)

# %%
# !pip install ydata-profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.4/400.4 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 24.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 61.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 44.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.9/65.9 kB 4.9 MB/s eta 0:00:00
# ...

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title="EDA do DataFrame df")
profile.to_notebook_iframe()

# %% [markdown]
# # Seleção de Colunas, Seleção de Linhas e de Linhas e Colunas
#
# <img src="https://pandas.pydata.org/docs/_images/03_subset_columns.svg" width=320, align="center">
# <img src="https://pandas.pydata.org/docs/_images/03_subset_rows.svg" width=320, align="center">
# <img src="https://pandas.pydata.org/docs/_images/03_subset_columns_rows.svg" width=320, align="center">

# %% [markdown]
# ## Seleção de 1 Coluna

# %%
df.head()
# Out:
#    district                           school   county grades  students  \
# 0     75119               Sunol Glen Unified  Alameda  KK-08       195
# 1     61499             Manzanita Elementary    Butte  KK-08       240
# 2     61549      Thermalito Union Elementary    Butte  KK-08      1550
# 3     61457  Golden Feather Union Elementary    Butte  KK-08       243
# 4     61523         Palermo Union Elementary    Butte  KK-08      1335
#
#     teachers   calworks      lunch  computer  expenditure     income  \
# 0  10.900000   0.510200   2.040800        67  6384.911133  22.690001
# 1  11.150000  15.416700  47.916698       101  5099.380859   9.824000
# 2  82.900002  55.032299  76.322601       169  5501.954590   8.978000
# 3  14.000000  36.475399  77.049202        85  7101.831055   8.978000
# 4  71.500000  33.108601  78.427002       171  5235.987793   9.080333
#
#      english        read        math
# 0   0.000000  691.599976  690.000000
# 1   4.583333  660.500000  661.900024
# ...

# %%
df['students']
# Out:
# 0       195
# 1       240
# 2      1550
# 3       243
# 4      1335
#        ...
# 415     984
# 416    3724
# 417     441
# 418     101
# 419    1778
# Name: students, Length: 420, dtype: int64

# %%
type(df['students']), type(df)
# Out:
# (pandas.core.series.Series, pandas.core.frame.DataFrame)

# %%
var = 'students'

df.students, df['students'], df[var]
# Out:
# (0       195
#  1       240
#  2      1550
#  3       243
#  4      1335
#         ...
#  415     984
#  416    3724
#  417     441
#  418     101
#  419    1778
#  Name: students, Length: 420, dtype: int64,
#  0       195
#  1       240
#  2      1550
#  3       243
#  4      1335
#         ...
#  415     984
#  416    3724
#  417     441
#  418     101
#  419    1778
#  Name: students, Length: 420, dtype: int64,
#  0       195
#  1       240
#  2      1550
#  3       243
#  4      1335
#         ...
#  415     984
#  416    3724
#  417     441
#  418     101
#  419    1778
#  Name: students, Length: 420, dtype: int64)

# %%
df.students.sum(), df.students.mean(), df.students.var(), df.students.quantile(0.1)
# Out:
# (np.int64(1104093),
#  np.float64(2628.792857142857),
#  15312390.622860562,
#  np.float64(164.0))

# %%
df.students / df.students.max()
# Out:
# 0      0.007175
# 1      0.008831
# 2      0.057036
# 3      0.008942
# 4      0.049124
#          ...
# 415    0.036208
# 416    0.137033
# 417    0.016228
# 418    0.003717
# 419    0.065425
# Name: students, Length: 420, dtype: float64

# %% [markdown]
# ## Cuidado: Series x DataFrame

# %%
df.students, df['students'], df[['students']]
# Out:
# (0       195
#  1       240
#  2      1550
#  3       243
#  4      1335
#         ...
#  415     984
#  416    3724
#  417     441
#  418     101
#  419    1778
#  Name: students, Length: 420, dtype: int64,
#  0       195
#  1       240
#  2      1550
#  3       243
#  4      1335
#         ...
#  415     984
#  416    3724
#  417     441
#  418     101
#  419    1778
#  Name: students, Length: 420, dtype: int64,
#       students
#  0         195
#  1         240
#  2        1550
#  3         243
#  4        1335
#  ..        ...
#  415       984
#  416      3724
#  417       441
#  418       101
#  419      1778
#
#  [420 rows x 1 columns])

# %%
df.students.mean(), df['students'].mean(), df[['students']].mean()
# Out:
# (np.float64(2628.792857142857),
#  np.float64(2628.792857142857),
#  students    2628.792857
#  dtype: float64)

# %%
print(df['students'])
# Out:
# 0       195
# 1       240
# 2      1550
# 3       243
# 4      1335
#        ...
# 415     984
# 416    3724
# 417     441
# 418     101
# 419    1778
# Name: students, Length: 420, dtype: int64

# %%
# %%script echo off
# df['students'].columns
# Out:
# off

# %%
print(df[['students']])
# Out:
#      students
# 0         195
# 1         240
# 2        1550
# 3         243
# 4        1335
# ..        ...
# 415       984
# 416      3724
# 417       441
# 418       101
# 419      1778
#
# [420 rows x 1 columns]

# %%
df[['students']].columns
# Out:
# Index(['students'], dtype='object')

# %%
df['students'].nlargest(5)
# Out:
# 48     27176
# 34     25151
# 159    21338
# 62     20927
# 106    19402
# Name: students, dtype: int64

# %%
df.grades.value_counts(), df.school.value_counts()
# Out:
# (grades
#  KK-08    359
#  KK-06     61
#  Name: count, dtype: int64,
#  school
#  Mountain View Elementary                  3
#  Lakeside Union Elementary                 3
#  Pleasant Valley Elementary                2
#  Jefferson Elementary                      2
#  Ocean View Elementary                     2
#                                           ..
#  Redwood City Elementary                   1
#  Twain Harte-Long Barn Union Elementary    1
#  Turlock Joint Elementary                  1
#  General Shafter Elementary                1
#  Cuddeback Union Elementary                1
#  Name: count, Length: 409, dtype: int64)

# %% [markdown]
# ## Seleção de $n$ colunas

# %%
df.head()
# Out:
#    district                           school   county grades  students  \
# 0     75119               Sunol Glen Unified  Alameda  KK-08       195
# 1     61499             Manzanita Elementary    Butte  KK-08       240
# 2     61549      Thermalito Union Elementary    Butte  KK-08      1550
# 3     61457  Golden Feather Union Elementary    Butte  KK-08       243
# 4     61523         Palermo Union Elementary    Butte  KK-08      1335
#
#     teachers   calworks      lunch  computer  expenditure     income  \
# 0  10.900000   0.510200   2.040800        67  6384.911133  22.690001
# 1  11.150000  15.416700  47.916698       101  5099.380859   9.824000
# 2  82.900002  55.032299  76.322601       169  5501.954590   8.978000
# 3  14.000000  36.475399  77.049202        85  7101.831055   8.978000
# 4  71.500000  33.108601  78.427002       171  5235.987793   9.080333
#
#      english        read        math
# 0   0.000000  691.599976  690.000000
# 1   4.583333  660.500000  661.900024
# ...

# %%
df[ ['students', 'computer'] ]
# Out:
#      students  computer
# 0         195        67
# 1         240       101
# 2        1550       169
# 3         243        85
# 4        1335       171
# ..        ...       ...
# 415       984       195
# 416      3724       721
# 417       441        45
# 418       101        14
# 419      1778       313
#
# [420 rows x 2 columns]

# %%
df[ ['students', 'computer'] ].mean()
# Out:
# students    2628.792857
# computer     303.383333
# dtype: float64

# %%
selecao = ['students', 'computer']

df[ selecao ]
# Out:
#      students  computer
# 0         195        67
# 1         240       101
# 2        1550       169
# 3         243        85
# 4        1335       171
# ..        ...       ...
# 415       984       195
# 416      3724       721
# 417       441        45
# 418       101        14
# 419      1778       313
#
# [420 rows x 2 columns]

# %% [markdown]
# ## Seleção de Linhas

# %%
df[ df.students > 25000 ]
# Out:
#     district                        school          county grades  students  \
# 34     67819  Ontario-Montclair Elementary  San Bernardino  KK-08     25151
# 48     63321   Bakersfield City Elementary            Kern  KK-08     27176
#
#        teachers   calworks      lunch  computer  expenditure     income  \
# 34  1186.699951  17.442600  80.195602      1713  5117.039551  11.722225
# 48  1429.000000  39.218399  84.294998      3324  5864.366211  12.109128
#
#       english        read        math
# 34  49.823071  625.400024  626.799988
# 48  28.863705  631.599976  629.500000

# %%
df[ (df.students > 10000) & (df.computer > 3000) ]
# Out:
#     district                       school county grades  students  teachers  \
# 48     63321  Bakersfield City Elementary   Kern  KK-08     27176    1429.0
#
#      calworks      lunch  computer  expenditure     income    english  \
# 48  39.218399  84.294998      3324  5864.366211  12.109128  28.863705
#
#           read   math
# 48  631.599976  629.5

# %%
(df.students > 10000) & (df.computer > 3000)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 415    False
# 416    False
# 417    False
# 418    False
# 419    False
# Length: 420, dtype: bool

# %% [markdown]
# ## Selecionar Colunas e Linhas

# %%
df[ df.students > 25000 ][['students', 'computer']]
# Out:
#     students  computer
# 34     25151      1713
# 48     27176      3324

# %%
df[ df.students > 25000 ].students
# Out:
# 34    25151
# 48    27176
# Name: students, dtype: int64
