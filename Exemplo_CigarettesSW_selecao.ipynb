# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/IMT_CD_2026/blob/main/Exemplo_CigarettesSW_selecao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/AER/CigarettesSW.csv")
df = df.drop(columns="rownames")
df.head()
# Out:
#   state  year    cpi  population       packs     income        tax  \
# 0    AL  1985  1.076     3973000  116.486282   46014968  32.500004
# 1    AR  1985  1.076     2327000  128.534592   26210736  37.000000
# 2    AZ  1985  1.076     3184000  104.522614   43956936  31.000000
# 3    CA  1985  1.076    26444000  100.363037  447102816  26.000000
# 4    CO  1985  1.076     3209000  112.963539   49466672  31.000000
#
#         price       taxs
# 0  102.181671  33.348335
# 1  101.474998  37.000000
# 2  108.578751  36.170418
# 3  107.837341  32.104000
# 4   94.266663  31.000000

# %% [markdown]
# # Explorando a estrutura

# %%
df.shape
# Out:
# (96, 9)

# %%
len(df)
# Out:
# 96

# %%
df.columns
# Out:
# Index(['state', 'year', 'cpi', 'population', 'packs', 'income', 'tax', 'price',
#        'taxs'],
#       dtype='object')

# %%
df.describe(include='all')
# Out:
#        state         year        cpi    population       packs        income  \
# count     96    96.000000  96.000000  9.600000e+01   96.000000  9.600000e+01
# unique    48          NaN        NaN           NaN         NaN           NaN
# top       AL          NaN        NaN           NaN         NaN           NaN
# freq       2          NaN        NaN           NaN         NaN           NaN
# mean     NaN  1990.000000   1.300000  5.168866e+06  109.182424  9.987874e+07
# std      NaN     5.026247   0.225176  5.442345e+06   25.871305  1.205411e+08
# min      NaN  1985.000000   1.076000  4.784470e+05   49.272198  6.887097e+06
# 25%      NaN  1985.000000   1.076000  1.622606e+06   92.450159  2.552038e+07
# 50%      NaN  1990.000000   1.300000  3.697472e+06  110.160660  6.166164e+07
# 75%      NaN  1995.000000   1.524000  5.901500e+06  123.523010  1.273140e+08
# max      NaN  1995.000000   1.524000  3.149352e+07  197.993988  7.714701e+08
#
#               tax       price        taxs
# ...

# %%
df.dtypes
# Out:
# state          object
# year            int64
# cpi           float64
# population      int64
# packs         float64
# income          int64
# tax           float64
# price         float64
# taxs          float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   state       96 non-null     object
#  1   year        96 non-null     int64
#  2   cpi         96 non-null     float64
#  3   population  96 non-null     int64
#  4   packs       96 non-null     float64
#  5   income      96 non-null     int64
#  6   tax         96 non-null     float64
#  7   price       96 non-null     float64
#  8   taxs        96 non-null     float64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 6.9+ KB

# %% [markdown]
# # Automatic EDA
#
# Opções: Sweetviz, Autoviz, YData Profiling (antigo Pandas Profiling)

# %%
# !pip install ydata-profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.4/400.4 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 2.1 MB/s eta 0:00:00
# ...

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title="EDA do DataFrame df")
profile.to_notebook_iframe()

# %% [markdown]
# ## Seleção de Colunas, Seleção de Linhas e de Linhas e Colunas
#
# <img src="https://pandas.pydata.org/docs/_images/03_subset_columns.svg" width=320, align="center">
# <img src="https://pandas.pydata.org/docs/_images/03_subset_rows.svg" width=320, align="center">
# <img src="https://pandas.pydata.org/docs/_images/03_subset_columns_rows.svg" width=320, align="center">

# %% [markdown]
# ## Seleção de 1 Coluna

# %%
df.head()
# Out:
#   state  year    cpi  population       packs     income        tax  \
# 0    AL  1985  1.076     3973000  116.486282   46014968  32.500004
# 1    AR  1985  1.076     2327000  128.534592   26210736  37.000000
# 2    AZ  1985  1.076     3184000  104.522614   43956936  31.000000
# 3    CA  1985  1.076    26444000  100.363037  447102816  26.000000
# 4    CO  1985  1.076     3209000  112.963539   49466672  31.000000
#
#         price       taxs
# 0  102.181671  33.348335
# 1  101.474998  37.000000
# 2  108.578751  36.170418
# 3  107.837341  32.104000
# 4   94.266663  31.000000

# %%
df['price']
# Out:
# 0     102.181671
# 1     101.474998
# 2     108.578751
# 3     107.837341
# 4      94.266663
#          ...
# 91    175.638748
# 92    239.109344
# 93    201.381256
# 94    166.517181
# 95    158.541656
# Name: price, Length: 96, dtype: float64

# %%
df.price
# Out:
# 0     102.181671
# 1     101.474998
# 2     108.578751
# 3     107.837341
# 4      94.266663
#          ...
# 91    175.638748
# 92    239.109344
# 93    201.381256
# 94    166.517181
# 95    158.541656
# Name: price, Length: 96, dtype: float64

# %%
type(df.price), type(df)
# Out:
# (pandas.core.series.Series, pandas.core.frame.DataFrame)

# %%
df['price'], df.price
# Out:
# (0     102.181671
#  1     101.474998
#  2     108.578751
#  3     107.837341
#  4      94.266663
#           ...
#  91    175.638748
#  92    239.109344
#  93    201.381256
#  94    166.517181
#  95    158.541656
#  Name: price, Length: 96, dtype: float64,
#  0     102.181671
#  1     101.474998
#  2     108.578751
#  3     107.837341
#  4      94.266663
#           ...
#  91    175.638748
#  92    239.109344
#  93    201.381256
#  94    166.517181
#  95    158.541656
#  Name: price, Length: 96, dtype: float64)

# %%
selecao = 'price'

df['price'], df.price, df[selecao]
# Out:
# (0     102.181671
#  1     101.474998
#  2     108.578751
#  3     107.837341
#  4      94.266663
#           ...
#  91    175.638748
#  92    239.109344
#  93    201.381256
#  94    166.517181
#  95    158.541656
#  Name: price, Length: 96, dtype: float64,
#  0     102.181671
#  1     101.474998
#  2     108.578751
#  3     107.837341
#  4      94.266663
#           ...
#  91    175.638748
#  92    239.109344
#  93    201.381256
#  94    166.517181
#  95    158.541656
#  Name: price, Length: 96, dtype: float64,
#  0     102.181671
#  1     101.474998
#  2     108.578751
#  3     107.837341
#  4      94.266663
#           ...
#  91    175.638748
#  92    239.109344
#  93    201.381256
#  94    166.517181
#  95    158.541656
#  Name: price, Length: 96, dtype: float64)

# %%
df.price.mean(), df['price'].sum(), df['price'].var(), df.price.quantile(0.10)
# Out:
# (np.float64(143.44793836275736),
#  np.float64(13771.002082824707),
#  1926.1077506168351,
#  np.float64(97.02925109863281))

# %%
df.price / df.price.max()
# Out:
# 0     0.424255
# 1     0.421321
# 2     0.450815
# 3     0.447737
# 4     0.391392
#         ...
# 91    0.729246
# 92    0.992774
# 93    0.836128
# 94    0.691374
# 95    0.658260
# Name: price, Length: 96, dtype: float64

# %% [markdown]
# ## Cuidado: Series x DataFrame

# %%
df['price'], df.price, df[['price']]
# Out:
# (0     102.181671
#  1     101.474998
#  2     108.578751
#  3     107.837341
#  4      94.266663
#           ...
#  91    175.638748
#  92    239.109344
#  93    201.381256
#  94    166.517181
#  95    158.541656
#  Name: price, Length: 96, dtype: float64,
#  0     102.181671
#  1     101.474998
#  2     108.578751
#  3     107.837341
#  4      94.266663
#           ...
#  91    175.638748
#  92    239.109344
#  93    201.381256
#  94    166.517181
#  95    158.541656
#  Name: price, Length: 96, dtype: float64,
#           price
#  0   102.181671
#  1   101.474998
#  2   108.578751
#  3   107.837341
#  4    94.266663
#  ..         ...
#  91  175.638748
#  92  239.109344
#  93  201.381256
#  94  166.517181
#  95  158.541656
#
#  [96 rows x 1 columns])

# %%
df['price'], df[['price']]
# Out:
# (0     102.181671
#  1     101.474998
#  2     108.578751
#  3     107.837341
#  4      94.266663
#           ...
#  91    175.638748
#  92    239.109344
#  93    201.381256
#  94    166.517181
#  95    158.541656
#  Name: price, Length: 96, dtype: float64,
#           price
#  0   102.181671
#  1   101.474998
#  2   108.578751
#  3   107.837341
#  4    94.266663
#  ..         ...
#  91  175.638748
#  92  239.109344
#  93  201.381256
#  94  166.517181
#  95  158.541656
#
#  [96 rows x 1 columns])

# %%
df['price'].mean(), df[['price']].mean()
# Out:
# (np.float64(143.44793836275736),
#  price    143.447938
#  dtype: float64)

# %%
df[['price']].columns
# Out:
# Index(['price'], dtype='object')

# %%
# %%script echo off
# df['price'].columns
# Out:
# off

# %%
df['price'].nlargest(5)
# Out:
# 67    240.849670
# 92    239.109344
# 84    224.459244
# 79    221.858002
# 68    220.348663
# Name: price, dtype: float64

# %%
df.state.value_counts()
# Out:
# state
# AL    2
# AR    2
# AZ    2
# CA    2
# CO    2
# CT    2
# DE    2
# FL    2
# GA    2
# IA    2
# ID    2
# IL    2
# IN    2
# KS    2
# KY    2
# LA    2
# MA    2
# MD    2
# ME    2
# MI    2
# MN    2
# MO    2
# MS    2
# MT    2
# NC    2
# ND    2
# NE    2
# NH    2
# NJ    2
# NM    2
# NV    2
# NY    2
# OH    2
# OK    2
# OR    2
# PA    2
# RI    2
# SC    2
# SD    2
# TN    2
# TX    2
# UT    2
# VA    2
# VT    2
# WA    2
# WI    2
# WV    2
# WY    2
# Name: count, dtype: int64

# %%
tips = pd.read_csv('https://raw.githubusercontent.com/Rogerio-mack/Visualizacao-de-Dados-em-Python/main/data/tips.csv')
tips.head()

tips.sex.value_counts(), tips['day'].value_counts()
# Out:
# (sex
#  Male      157
#  Female     87
#  Name: count, dtype: int64,
#  day
#  Sat     87
#  Sun     76
#  Thur    62
#  Fri     19
#  Name: count, dtype: int64)

# %% [markdown]
# ## Seleção de $n$ colunas

# %%
df.head()
# Out:
#   state  year    cpi  population       packs     income        tax  \
# 0    AL  1985  1.076     3973000  116.486282   46014968  32.500004
# 1    AR  1985  1.076     2327000  128.534592   26210736  37.000000
# 2    AZ  1985  1.076     3184000  104.522614   43956936  31.000000
# 3    CA  1985  1.076    26444000  100.363037  447102816  26.000000
# 4    CO  1985  1.076     3209000  112.963539   49466672  31.000000
#
#         price       taxs
# 0  102.181671  33.348335
# 1  101.474998  37.000000
# 2  108.578751  36.170418
# 3  107.837341  32.104000
# 4   94.266663  31.000000

# %%
df[ ['state','price'] ]
# Out:
#    state       price
# 0     AL  102.181671
# 1     AR  101.474998
# 2     AZ  108.578751
# 3     CA  107.837341
# 4     CO   94.266663
# ..   ...         ...
# 91    VT  175.638748
# 92    WA  239.109344
# 93    WI  201.381256
# 94    WV  166.517181
# 95    WY  158.541656
#
# [96 rows x 2 columns]

# %%
df[ ['state','income', 'price'] ]
# Out:
#    state     income       price
# 0     AL   46014968  102.181671
# 1     AR   26210736  101.474998
# 2     AZ   43956936  108.578751
# 3     CA  447102816  107.837341
# 4     CO   49466672   94.266663
# ..   ...        ...         ...
# 91    VT   12448607  175.638748
# 92    WA  129680832  239.109344
# 93    WI  115959680  201.381256
# 94    WV   32611268  166.517181
# 95    WY   10293195  158.541656
#
# [96 rows x 3 columns]

# %%
df[ ['income', 'price'] ].mean()
# Out:
# income    9.987874e+07
# price     1.434479e+02
# dtype: float64

# %%
selecao = ['income', 'price']

df[ selecao ].mean()
# Out:
# income    9.987874e+07
# price     1.434479e+02
# dtype: float64

# %% [markdown]
# ## Seleção de Linhas

# %%
df.head()
# Out:
#   state  year    cpi  population       packs     income        tax  \
# 0    AL  1985  1.076     3973000  116.486282   46014968  32.500004
# 1    AR  1985  1.076     2327000  128.534592   26210736  37.000000
# 2    AZ  1985  1.076     3184000  104.522614   43956936  31.000000
# 3    CA  1985  1.076    26444000  100.363037  447102816  26.000000
# 4    CO  1985  1.076     3209000  112.963539   49466672  31.000000
#
#         price       taxs
# 0  102.181671  33.348335
# 1  101.474998  37.000000
# 2  108.578751  36.170418
# 3  107.837341  32.104000
# 4   94.266663  31.000000

# %%
df[ df.state == 'AL' ]
# Out:
#    state  year    cpi  population       packs    income        tax  \
# 0     AL  1985  1.076     3973000  116.486282  46014968  32.500004
# 48    AL  1995  1.524     4262731  101.085434  83903280  40.500004
#
#          price       taxs
# 0   102.181671  33.348335
# 48  158.371338  41.904671

# %%
df[ df.price < 90 ]
# Out:
#    state  year    cpi  population       packs    income   tax      price  \
# 14    KY  1985  1.076     3695000  186.035187  42703144  19.0  87.001251
# 24    NC  1985  1.076     6255000  155.283768  79104656  18.0  84.967995
#
#          taxs
# 14  23.142918
# 24  21.268000

# %%
df[ (df.state == 'AL') & (df.price < 150) ]
# Out:
#   state  year    cpi  population       packs    income        tax       price  \
# 0    AL  1985  1.076     3973000  116.486282  46014968  32.500004  102.181671
#
#         taxs
# 0  33.348335

# %%
(df.state == 'AL') # & (df.price < 150)
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 91    False
# 92    False
# 93    False
# 94    False
# 95    False
# Name: state, Length: 96, dtype: bool

# %%
selecao = (df.state == 'AL') & (df.price < 150)

df[ selecao ]
# Out:
#   state  year    cpi  population       packs    income        tax       price  \
# 0    AL  1985  1.076     3973000  116.486282  46014968  32.500004  102.181671
#
#         taxs
# 0  33.348335

# %% [markdown]
# ## Selecionar Colunas e Linhas

# %%
df[ df.price < 90 ]['price']
# Out:
# 14    87.001251
# 24    84.967995
# Name: price, dtype: float64

# %%
df[ df.price < 90 ].price
# Out:
# 14    87.001251
# 24    84.967995
# Name: price, dtype: float64

# %%
df[ df.price < 90 ][ ['income', 'price'] ]
# Out:
#       income      price
# 14  42703144  87.001251
# 24  79104656  84.967995

# %% [markdown]
# ### **Não é um boa prática**

# %%
df[ ['income', 'price'] ][ df.price < 90 ]
# Out:
#       income      price
# 14  42703144  87.001251
# 24  79104656  84.967995

# %% [markdown]
# ## Operação Fechada

# %%
df[ df.price < 90 ][ ['income', 'price'] ].head(1)
# Out:
#       income      price
# 14  42703144  87.001251

# %%
df[ df.price < 90 ][ ['income', 'price'] ].describe()
# Out:
#              income      price
# count  2.000000e+00   2.000000
# mean   6.090390e+07  85.984623
# std    2.573976e+07   1.437729
# min    4.270314e+07  84.967995
# 25%    5.180352e+07  85.476309
# 50%    6.090390e+07  85.984623
# 75%    7.000428e+07  86.492937
# max    7.910466e+07  87.001251

# %%
df2 = df[ df.price < 90 ][ ['income', 'price'] ]

df2.head()
# Out:
#       income      price
# 14  42703144  87.001251
# 24  79104656  84.967995
