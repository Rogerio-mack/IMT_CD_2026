# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/IMT_CD_2026/blob/main/Vetorizacao_apply.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Vetorização de Strings

# %%
df = pd.read_csv('https://github.com/Rogerio-mack/IMT_CD_2026/raw/refs/heads/main/data/movie.csv')
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df.director_name.str.upper()
# Out:
# 0           JAMES CAMERON
# 1          GORE VERBINSKI
# 2              SAM MENDES
# 3       CHRISTOPHER NOLAN
# 4             DOUG WALKER
#               ...
# 4911          SCOTT SMITH
# 4912                  NaN
# 4913     BENJAMIN ROBERDS
# 4914          DANIEL HSIA
# 4915             JON GUNN
# Name: director_name, Length: 4916, dtype: object

# %%
df.director_name.str.len()
# Out:
# 0       13.0
# 1       14.0
# 2       10.0
# 3       17.0
# 4       11.0
#         ...
# 4911    11.0
# 4912     NaN
# 4913    16.0
# 4914    11.0
# 4915     8.0
# Name: director_name, Length: 4916, dtype: float64

# %% [markdown]
# # Linhas com director_name LIKE %Chris%

# %%
df[ df.director_name.str.contains('Chris',na=False) ]
# Out:
#       color             director_name  num_critic_for_reviews  duration  \
# 3     Color         Christopher Nolan                   813.0     164.0
# 24    Color               Chris Weitz                   251.0     113.0
# 66    Color         Christopher Nolan                   645.0     152.0
# 96    Color         Christopher Nolan                   712.0     169.0
# 97    Color         Christopher Nolan                   642.0     148.0
# ...     ...                       ...                     ...       ...
# 4576  Color        Christopher Hutson                     8.0      95.0
# 4586  Color  Christopher Scott Cherot                    25.0      84.0
# 4589  Color              Chris Atkins                    21.0     103.0
# 4614  Color              Chris Kentis                   235.0      79.0
# 4791  Color              Chris Marker                    16.0      59.0
#
#       director_facebook_likes  actor_3_facebook_likes          actor_2_name  \
# ...

# %%
df[ df.director_name.str.find('Chris') >= 0 ]
# Out:
#       color             director_name  num_critic_for_reviews  duration  \
# 3     Color         Christopher Nolan                   813.0     164.0
# 24    Color               Chris Weitz                   251.0     113.0
# 66    Color         Christopher Nolan                   645.0     152.0
# 96    Color         Christopher Nolan                   712.0     169.0
# 97    Color         Christopher Nolan                   642.0     148.0
# ...     ...                       ...                     ...       ...
# 4576  Color        Christopher Hutson                     8.0      95.0
# 4586  Color  Christopher Scott Cherot                    25.0      84.0
# 4589  Color              Chris Atkins                    21.0     103.0
# 4614  Color              Chris Kentis                   235.0      79.0
# 4791  Color              Chris Marker                    16.0      59.0
#
#       director_facebook_likes  actor_3_facebook_likes          actor_2_name  \
# ...

# %% [markdown]
# # Criando uma coluna `director_first_name`

# %%
df.director_name.str.split()
# Out:
# 0           [James, Cameron]
# 1          [Gore, Verbinski]
# 2              [Sam, Mendes]
# 3       [Christopher, Nolan]
# 4             [Doug, Walker]
#                 ...
# 4911          [Scott, Smith]
# 4912                     NaN
# 4913     [Benjamin, Roberds]
# 4914          [Daniel, Hsia]
# 4915             [Jon, Gunn]
# Name: director_name, Length: 4916, dtype: object

# %%
df.director_name.str.split(expand=True)
# Out:
#                 0          1     2     3
# 0           James    Cameron  None  None
# 1            Gore  Verbinski  None  None
# 2             Sam     Mendes  None  None
# 3     Christopher      Nolan  None  None
# 4            Doug     Walker  None  None
# ...           ...        ...   ...   ...
# 4911        Scott      Smith  None  None
# 4912          NaN        NaN   NaN   NaN
# 4913     Benjamin    Roberds  None  None
# 4914       Daniel       Hsia  None  None
# 4915          Jon       Gunn  None  None
#
# [4916 rows x 4 columns]

# %%
df['director_first_name'] = df.director_name.str.split(expand=True)[0]
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# # `Apply`

# %%
df.duration / 60
# Out:
# 0       2.966667
# 1       2.816667
# 2       2.466667
# 3       2.733333
# 4            NaN
#           ...
# 4911    1.450000
# 4912    0.716667
# 4913    1.266667
# 4914    1.666667
# 4915    1.500000
# Name: duration, Length: 4916, dtype: float64

# %%
def converte_horas(minutos):
  return minutos / 60

# %%
df.duration.apply(converte_horas)
# Out:
# 0       2.966667
# 1       2.816667
# 2       2.466667
# 3       2.733333
# 4            NaN
#           ...
# 4911    1.450000
# 4912    0.716667
# 4913    1.266667
# 4914    1.666667
# 4915    1.500000
# Name: duration, Length: 4916, dtype: float64

# %%
df.duration.apply(lambda x: x/60)
# Out:
# 0       2.966667
# 1       2.816667
# 2       2.466667
# 3       2.733333
# 4            NaN
#           ...
# 4911    1.450000
# 4912    0.716667
# 4913    1.266667
# 4914    1.666667
# 4915    1.500000
# Name: duration, Length: 4916, dtype: float64

# %% [markdown]
# ## Apply over row

# %%
df.apply(lambda x: x.duration/60,axis=1)
# Out:
# 0       2.966667
# 1       2.816667
# 2       2.466667
# 3       2.733333
# 4            NaN
#           ...
# 4911    1.450000
# 4912    0.716667
# 4913    1.266667
# 4914    1.666667
# 4915    1.500000
# Length: 4916, dtype: float64

# %%
def score_director(num_critic_for_reviews,director_facebook_likes):

  if director_facebook_likes > 0:
    return num_critic_for_reviews * director_facebook_likes
  else:
    return num_critic_for_reviews

# %%
df.apply(lambda row: score_director(row.num_critic_for_reviews,row.director_facebook_likes), axis=1)
# Out:
# 0            723.0
# 1         170026.0
# 2            602.0
# 3       17886000.0
# 4              NaN
#            ...
# 4911           2.0
# 4912          43.0
# 4913          13.0
# 4914          14.0
# 4915         688.0
# Length: 4916, dtype: float64

# %%
def score_director(row):

  if row.director_facebook_likes > 0:
    return row.num_critic_for_reviews * row.director_facebook_likes
  else:
    return row.num_critic_for_reviews

# %%
df.apply(lambda row: score_director(row), axis=1)
# Out:
# 0            723.0
# 1         170026.0
# 2            602.0
# 3       17886000.0
# 4              NaN
#            ...
# 4911           2.0
# 4912          43.0
# 4913          13.0
# 4914          14.0
# 4915         688.0
# Length: 4916, dtype: float64

# %%
df.apply(score_director,axis=1)
# Out:
# 0            723.0
# 1         170026.0
# 2            602.0
# 3       17886000.0
# 4              NaN
#            ...
# 4911           2.0
# 4912          43.0
# 4913          13.0
# 4914          14.0
# 4915         688.0
# Length: 4916, dtype: float64

# %% [markdown]
# ## Partindo de `df.director_name.str.split()` como gerar o first_name com uma função `apply`

# %%
df.director_name.str.split()
# Out:
# 0           [James, Cameron]
# 1          [Gore, Verbinski]
# 2              [Sam, Mendes]
# 3       [Christopher, Nolan]
# 4             [Doug, Walker]
#                 ...
# 4911          [Scott, Smith]
# 4912                     NaN
# 4913     [Benjamin, Roberds]
# 4914          [Daniel, Hsia]
# 4915             [Jon, Gunn]
# Name: director_name, Length: 4916, dtype: object

# %%
# %%script echo skipping error
# df.director_name.str.split().apply(lambda lista: lista[0])
# Out:
# skipping error

# %%
df.director_name.str.split().isnull().sum()
# Out:
# np.int64(102)

# %%
def extrai_primeiro(lista):
  if isinstance(lista,list):
    return lista[0]
  else:
    return None

# %%
def extrai_primeiro(lista):
  try:
    return lista[0]
  except:
    return None

# %%
df.director_name.str.split().apply(extrai_primeiro)
# Out:
# 0             James
# 1              Gore
# 2               Sam
# 3       Christopher
# 4              Doug
#            ...
# 4911          Scott
# 4912           None
# 4913       Benjamin
# 4914         Daniel
# 4915            Jon
# Name: director_name, Length: 4916, dtype: object

# %%
df.director_name.str.split().apply(lambda lista: lista[0] if isinstance(lista, list) else None)
# Out:
# 0             James
# 1              Gore
# 2               Sam
# 3       Christopher
# 4              Doug
#            ...
# 4911          Scott
# 4912           None
# 4913       Benjamin
# 4914         Daniel
# 4915            Jon
# Name: director_name, Length: 4916, dtype: object

# %% [markdown]
# # Expressões Regulares

# %%
df = pd.read_csv('https://github.com/Rogerio-mack/IMT_CD_2026/raw/main/data/restaurant_inspections2.csv')
df.head()
# Out:
#                 Name        Date         Info  \
# 0  E & E Grill House  2017-08-08      Borough
# 1  E & E Grill House  2017-08-08      Cuisine
# 2  E & E Grill House  2017-08-08  Description
# 3  E & E Grill House  2017-08-08        Grade
# 4  E & E Grill House  2017-08-08        Score
#
#                                                Value
# 0                                          MANHATTAN
# 1                                           American
# 2  Non-food contact surface improperly constructe...
# 3                                                  A
# 4                                                9.0

# %% [markdown]
# ## Selecionar somente os registros com `date` no formato 9999-99-99

# %%
df['Date'].str.match("^\d{4}-\d{2}-\d{2}$")
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 495    True
# 496    True
# 497    True
# 498    True
# 499    True
# Name: Date, Length: 500, dtype: bool

# %% [markdown]
# ### Datas no formato 9999-99-99

# %%
df[ df['Date'].str.match("^\d{4}-\d{2}-\d{2}$") ]
# Out:
#                               Name        Date         Info  \
# 0                E & E Grill House  2017-08-08      Borough
# 1                E & E Grill House  2017-08-08      Cuisine
# 2                E & E Grill House  2017-08-08  Description
# 3                E & E Grill House  2017-08-08        Grade
# 4                E & E Grill House  2017-08-08        Score
# ..                             ...         ...          ...
# 495  PIER SIXTY ONE-THE LIGHTHOUSE  2017-09-01      Borough
# 496  PIER SIXTY ONE-THE LIGHTHOUSE  2017-09-01      Cuisine
# 497  PIER SIXTY ONE-THE LIGHTHOUSE  2017-09-01  Description
# 498  PIER SIXTY ONE-THE LIGHTHOUSE  2017-09-01        Grade
# 499  PIER SIXTY ONE-THE LIGHTHOUSE  2017-09-01        Score
#
#                                                  Value
# 0                                            MANHATTAN
# 1                                             American
# 2    Non-food contact surface improperly constructe...
# ...

# %% [markdown]
# ### Datas NÃO no formato 9999-99-99

# %%
df[ ~ df['Date'].str.match("^\d{4}-\d{2}-\d{2}$") ]
# Out:
#                   Name        Date         Info  \
# 10  NY SWEET SPOT CAFE  2023/13/33      Borough
# 11  NY SWEET SPOT CAFE  2023/13/33      Cuisine
# 12  NY SWEET SPOT CAFE  2023/13/33  Description
# 13  NY SWEET SPOT CAFE  2023/13/33        Grade
# 14  NY SWEET SPOT CAFE  2023/13/33        Score
#
#                                                 Value
# 10                                           BROOKLYN
# 11                                   Eastern European
# 12  Plumbing not properly installed or maintained;...
# 13                                                  A
# 14                                                7.0

# %% [markdown]
# ### Com `import re` e `apply`

# %%
import re

def valida_data(data):
  regex = r"^\d{4}-\d{2}-\d{2}$"
  return re.match(regex, data) is not None

# %%
df['Date'].apply(valida_data)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 495    True
# 496    True
# 497    True
# 498    True
# 499    True
# Name: Date, Length: 500, dtype: bool

# %%
df[ ~ df['Date'].apply(valida_data) ]
# Out:
#                   Name        Date         Info  \
# 10  NY SWEET SPOT CAFE  2023/13/33      Borough
# 11  NY SWEET SPOT CAFE  2023/13/33      Cuisine
# 12  NY SWEET SPOT CAFE  2023/13/33  Description
# 13  NY SWEET SPOT CAFE  2023/13/33        Grade
# 14  NY SWEET SPOT CAFE  2023/13/33        Score
#
#                                                 Value
# 10                                           BROOKLYN
# 11                                   Eastern European
# 12  Plumbing not properly installed or maintained;...
# 13                                                  A
# 14                                                7.0

# %% [markdown]
# ## Validando datas reais, `date` YYYY-MM-DD, isto é, valores válidos

# %%
from datetime import datetime

# %%
datetime.strptime('1999-12-01','%Y-%m-%d')
# Out:
# datetime.datetime(1999, 12, 1, 0, 0)

# %%
# %%script echo skipping error
# datetime.strptime('1999-13-01','%Y-%m-%d')
# Out:
# skipping error

# %%
def valida_data(data):
  try:
    datetime.strptime(data,'%Y-%m-%d')
    return True
  except:
    return False

# %%
df[ ~ df['Date'].apply(valida_data) ]
# Out:
#                                        Name        Date         Info  \
# 10                       NY SWEET SPOT CAFE  2023/13/33      Borough
# 11                       NY SWEET SPOT CAFE  2023/13/33      Cuisine
# 12                       NY SWEET SPOT CAFE  2023/13/33  Description
# 13                       NY SWEET SPOT CAFE  2023/13/33        Grade
# 14                       NY SWEET SPOT CAFE  2023/13/33        Score
# 22                       BRANDY'S PIANO BAR  2023-13-33  Description
# 23                       BRANDY'S PIANO BAR  2023-13-33        Grade
# 24                       BRANDY'S PIANO BAR  2023-13-33        Score
# 220              MAY KAIDEE/DESI FOOD TRUCK  2023-13-33      Borough
# 221              MAY KAIDEE/DESI FOOD TRUCK  2023-13-33      Cuisine
# 222              MAY KAIDEE/DESI FOOD TRUCK  2023-13-33  Description
# 223              MAY KAIDEE/DESI FOOD TRUCK  2023-13-33        Grade
# 224              MAY KAIDEE/DESI FOOD TRUCK  2023-13-33        Score
# ...
